# %% [markdown]
# # Modified PilotNet Model Training, Conversion to ONNX

# %%
# !pip install onnx onnxscript

import sys
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
sys.path.append('/content/drive/MyDrive/autonomousPipeline/packages/cond_imitation_learning_pkg/src')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from train import train_model

dataset_path = '/content/drive/MyDrive/autonomousPipeline/dataset/cil_dataset_20260617-160001'

train_model(data_path=dataset_path, epochs=100, batch_size=64)

# %%
from export import compile_to_onnx

compile_to_onnx(data_path=dataset_path)
